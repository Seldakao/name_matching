# %%
import pandas as pd
import string
from sklearn.feature_extraction.text import CountVectorizer
import time
from nltk.metrics.distance import edit_distance
from nltk.metrics.distance import jaccard_distance


STrain = pd.read_csv('STrain.csv', sep = '|')
G = pd.read_csv('G.csv', sep = '|')
merge = STrain.merge(G, how = 'left', on = 'company_id', suffixes = ['STrain','R'])

# Remove punctuations and lowercase

def remove_punctuations(X):
    translator = X.maketrans('', '', string.punctuation)
    return X.translate(translator)

# remove lowercase for comparing initials, remove space directly
def remove_lowercase(X):
    translator = X.maketrans('', '', string.ascii_lowercase)
    return X.translate(translator).replace(' ','')

def remove_whitespace(X):
    # remove the space and make lowercase here
    return X.replace(' ', '')

def make_lower(X):
    # convert to lower case
    return X.lower()

# remove all the punctuations
G['name_no_punc'] = G['name'].apply(remove_punctuations)
# after removing the punctuations, creating another one with only capital letters
G['name_capital'] =G['name_no_punc'].apply(remove_lowercase)
G['name_no_punc'] = G['name_no_punc'].apply(make_lower)
G['name_no_punc_no_space'] = G['name_no_punc'].apply(remove_whitespace)

# Same transformation for STrain
STrain['name_no_punc'] = STrain['name'].apply(remove_punctuations)
STrain['name_capital'] =STrain['name_no_punc'].apply(remove_lowercase)
STrain['name_no_punc'] = STrain['name_no_punc'].apply(make_lower)
STrain['name_no_punc_no_space'] = STrain['name_no_punc'].apply(remove_whitespace)

print('There are total', STrain[STrain['company_id'] == -1].shape[0], 'unmatched companies.')
# Out:
# There are total 30348 unmatched companies.

# %%
import time
from nltk.metrics.distance import edit_distance
from nltk.metrics.distance import jaccard_distance
def find_the_word(X, Matrix):
    '''Find the word in bag of words of G
         using the column "name_no_punc" '''
    
    t = time.time()
    # split the name into separate words
    words = X.split()
    length = len(words)
    # Find the word in the bag of words of G
    found = False
    j = 0
    while (found == False) & (j < length):
        found = words[j] in Matrix.columns 
        j = j + 1
        
    if found:
        sub_matrix = Matrix[Matrix[words[j-1]]>=1]
        return sub_matrix.index # return index
    else:
        return None
    
def find_the_word_whole(X,Matrix):
    to_compare_dict = {}
    '''Input the whole training company (name_no_punc), and output the index to dictionary'''
    for i in X.index:
        words = X.loc[i].split()
        length = len(words)
        # Find the word in the bag of words of G
        found = False
        j = 0
        while (found == False) & (j < length):
            found = words[j] in Matrix.columns 
            j = j + 1
        
        if found:
            to_compare_dict[i] = Matrix[Matrix[words[j-1]]>=1]
           
        else:
            to_compare_dict[i] = None
                
        return to_compare_dict
    
    
    
def compare_jacaard(to_compared,X,jd_threshold):
    '''use the column "name_no_punc_no_space" '''
    best_matching_index = -1
    for k in to_compared.index:
        jd = jaccard_distance(set(to_compared.loc[k]), set(X))
        if jd <= jd_threshold:
            best_matching_index = k
            break
    
    return best_matching_index

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(max_df=0.03)
matrix = vectorizer.fit_transform(G['name_no_punc']).todense() 
#sum_words = matrix.sum(axis=0) 
features = vectorizer.get_feature_names()
#word_count = pd.DataFrame(sum_words,index = features, column = ['count'])
#words_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
#words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
#print( vectorizer.vocabulary_ )

# %%
# Try TF-IDF and compute cosine similarity for Train and G
t = time.time()
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(min_df=1, analyzer='char', ngram_range = (3,3))
tf_idf_G = tfidf.fit_transform(G['name_no_punc'])
timespent = time.time() - t
print('TD-IDF of G takes {} seconds'.format(timespent))
# Out:
# TD-IDF of G takes 11.448935985565186 seconds

# %%
# Try TF-IDF and compute cosine similarity for Train and G (space removed)
t = time.time()
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_nospace = TfidfVectorizer(min_df=1, analyzer='char', ngram_range = (2,4))
tf_idf_G = tfidf_nospace.fit_transform(G['name_no_punc_no_space'])
timespent = time.time() - t
print('TD-IDF of G takes {} seconds'.format(timespent))
# Out:
# TD-IDF of G takes 31.79740595817566 seconds

# %%
# Transform train with tfidf
t = time.time()
tf_idf_STrain = tfidf.transform(STrain['name_no_punc'])
timespent = time.time() - t
print('TD-IDF of STrain takes {} seconds'.format(timespent))
# Out:
# TD-IDF of STrain takes 2.4644408226013184 seconds

# %%
from sklearn.metrics.pairwise import cosine_similarity
t = time.time()
similarity_score = cosine_similarity(tf_idf_G, tf_idf_STrain, dense_output=False)
timespent = time.time() - t
print('cosine similarity takes {} seconds'.format(timespent))

# %%
from  scipy.sparse import find
from sklearn.metrics.pairwise import cosine_similarity

def matching(Sample_slice,tf_idf_G, threshold):
    '''Sample_slice is a sparse matrix'''
    i,v, j =find(Sample_slice)
    # V are the nonzero columns
    x,y,z = find(tf_idf_G[:,v])
    sub_G = tf_idf_G[:,v]
    slice_G = sub_G[x,:]
    similarity_score = cosine_similarity(slice_G, Sample_slice[:,v], dense_output=True)
    max_index= similarity_score.argmax()
    if max_index >= threshold:
        return x[max_index]
    else:
        return -1

# %%
tf_idf_G[0,[1,2]]
# Out:
# <1x2 sparse matrix of type '<class 'numpy.float64'>'
# 	with 0 stored elements in Compressed Sparse Row format>

# %%
grams = tfidf.get_feature_names()

# %%
t = time.time()
Sample = tf_idf_STrain[0:100]
predict = []
for i in range(Sample.shape[0]):
    pred = matching(Sample[i,:],tf_idf_G, 0.75)
    predict.append(pred)
    
timespent = time.time() - t
print('sample matching takes {} seconds'.format(timespent))
# Out:
# sample matching takes 15.51825499534607 seconds

# %%
company_id[predict]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/series.py:842: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self.loc[key]
#  342766    250537.0
#  84431     356624.0
#  422974    420749.0
#  432988    523467.0
#  75219     231108.0
#  391805    111934.0
#  188971    355140.0
#  273215    205639.0
#  372128    485612.0
#  330810    589052.0
#  329018    210358.0
#  335331      9529.0
#  206289    453809.0
#  300020     85684.0
# -1              NaN
#  10345     253824.0
#  56044     545661.0
#  215261    524676.0
#  14081      95247.0
# -1              NaN
#  314718    271364.0
#  215941    151846.0
#  312791    197835.0
#  397251    293343.0
#  161147    164015.0
#  229674    607912.0
#  268070    168375.0
#  261931    177092.0
#  275565    340707.0
#  298655    477352.0
#              ...
#  26226     524563.0
#  376762    105633.0
#  385       461136.0
#  80081     173621.0
#  157175    125258.0
#  239768    177010.0
#  220547    594766.0
#  227734    154285.0
#  133048    600713.0
#  23593     629407.0
#  265943    169190.0
#  114017    206579.0
#  111223    164752.0
#  285267    629724.0
#  425638    421753.0
#  226572    293623.0
#  92614     612614.0
#  428387    329427.0
#  170422    571672.0
#  67551     497819.0
#  162388      1577.0
#  344176    100431.0
#  163983    476919.0
#  304177    142481.0
#  183529    481051.0
#  431217     19650.0
#  254855    268565.0
#  375166     60865.0
#  314675     50919.0
#  4662      580032.0
# Name: company_id, Length: 100, dtype: float64

# %%
Sample = STrain.sample(n = 100)
Sample.head()
# Out:
#        train_index                                               name  \
# 16613        16613                                      MP Prope. LLC
# 10499        10499                             Humanagroup Holding AB
# 4300          4300  Ianc Partners Funds, Artisan. - Ianc Developin...
# 3671          3671                                             BBM SA
# 31073        31073                       Captal Impera Spółka Akcyjna
#
#        company_id                                       name_no_punc  \
# 16613          -1                                       mp prope llc
# 10499      320888                             humanagroup holding ab
# 4300       475596  ianc partners funds artisan  ianc developing w...
# 3671       354740                                             bbm sa
# 31073          -1                       captal impera spółka akcyjna
#
#       name_capital                            name_no_punc_no_space
# 16613       MPPLLC                                       mppropellc
# 10499         HHAB                             humanagroupholdingab
# 4300      IPFAIDWF  iancpartnersfundsartisaniancdevelopingworldfund
# 3671         BBMSA                                            bbmsa
# 31073       CISółA                        captalimperaspółkaakcyjna

# %%
ans = company_id[[1,2,1]]

# %%
ANS = pd.DataFrame([],columns=['company_id'],index= [4,5,6])

# %%
ANS['company_id'] = company_id

# %%
G.reset_index()
# Out:
#          index  company_id                                               name  \
# 0            0      634022                                         PRIMCOM SA
# 1            1      324497                              The David Isaacs Fund
# 2            2      280848                         Bramor Enterprises Limited
# 3            3      432662                                       NAVEXIM S.A.
# 4            4      524224                                     Magal Group SA
# 5            5      513585                                     Marly SPF S.A.
# 6            6      354496                               I.T APPARELS LIMITED
# 7            7      381944                                      VX 30.141 ApS
# 8            8      526057  Rydex ETF Trust - Guggenheim S&P 500 Equal Wei...
# 9            9       34381                Rydex Series Funds - Retailing Fund
# 10          10      170089                                Olam Holdings, Inc.
# 11          11      425961                                   Fire Holding A/S
# 12          12      606644                                   Aarhus Murerlaug
# 13          13      449644                   Indigo Hall SC JV Investors, LLC
# 14          14       85335                               Hestbech Holding ApS
# 15          15      338841                                    Pharmatrade A/S
# 16          16      280937  GS+A Tactical Fixed Income Master Fund (Cayman...
# 17          17      622744                                 Lars Nielsens Fond
# 18          18      260264             Temasek Financial (II) Private Limited
# 19          19      561089                                    REINSON LIMITED
# 20          20      632695  TULLETT PREBON BRASIL CORRETORA DE VALORES E C...
# 21          21      103863                                   Bright Think Ltd
# 22          22      256892                                   NK-Forsyning A/S
# 23          23      133701              Holdingselskabet Henrik V. Larsen A/S
# 24          24       80822                                  Strandtorget 1 AS
# 25          25      637249                                       Rosshavet AS
# 26          26      596390                                  Western Edge Inc.
# 27          27      366252                                          Consto AS
# 28          28      140358                          Sommerlade Consulting APS
# 29          29      115667                           Nano One Materials Corp.
# ...        ...         ...                                                ...
# 450226  450226      348330           DCI Umbrella Fund Public Limited Company
# 450227  450227      510306                                           DCI, LLC
# 450228  450228      334917                         Česká exportní banka, a.s.
# 450229  450229      540797                               Komerční banka, a.s.
# 450230  450230      557856                   COMPAGNIE DE FINANCEMENT FONCIER
# 450231  450231      127359                            AMUNDI ASSET MANAGEMENT
# 450232  450232      549956                                                AXA
# 450233  450233      350077                                 AMUNDI CREDIT EURO
# 450234  450234      302899                    CREDIT INDUSTRIEL ET COMMERCIAL
# 450235  450235      255907                        AMUNDI OBLIG HAUT RENDEMENT
# 450236  450236      239536                 BANQUE FEDERATIVE DU CREDIT MUTUEL
# 450237  450237      482822                                        AMUNDI 24 M
# 450238  450238       70003  "CASSA CENTRALE BANCA - CREDITO COOPERATIVO DE...
# 450239  450239      283503  MEDIOLANUM GESTIONE FONDI - SOCIETA' DI GESTIO...
# 450240  450240        4804                                     NIBC Bank N.V.
# 450241  450241      219015                                      KAS BANK N.V.
# 450242  450242      452876                                   Kempen & Co N.V.
# 450243  450243      316806                                         AEGON N.V.
# 450244  450244      428951                             AEGON Derivatives N.V.
# 450245  450245      478239                        ABN AMRO Clearing Bank N.V.
# 450246  450246      554608          Stichting Pensioenfonds Horeca & Catering
# 450247  450247      497982                    Stichting Pensioenfonds Staples
# 450248  450248       37736      BNP PARIBAS ASSET MANAGEMENT Netherlands N.V.
# 450249  450249      369911                  Stichting Pensioenfonds Hoogovens
# 450250  450250      477477                            BFT INVESTMENT MANAGERS
# 450251  450251      614780    GL Europe Select Opportunities Investments Sarl
# 450252  450252       26499                    JACMA S.A. - SPF en Liquidation
# 450253  450253      581457                          GL EUROPE LUXEMBOURG SARL
# 450254  450254      401977                        MAX MARA INTERNATIONAL S.A.
# 450255  450255      497444              Brookfield Renewable Supply 2 Limited
#
#                                              name_no_punc  \
# 0                                              primcom sa
# 1                                   the david isaacs fund
# 2                              bramor enterprises limited
# 3                                              navexim sa
# 4                                          magal group sa
# 5                                            marly spf sa
# 6                                     it apparels limited
# 7                                            vx 30141 aps
# 8       rydex etf trust  guggenheim sp 500 equal weigh...
# 9                      rydex series funds  retailing fund
# 10                                      olam holdings inc
# 11                                        fire holding as
# 12                                       aarhus murerlaug
# 13                        indigo hall sc jv investors llc
# 14                                   hestbech holding aps
# 15                                         pharmatrade as
# 16        gsa tactical fixed income master fund cayman lp
# 17                                     lars nielsens fond
# 18                   temasek financial ii private limited
# 19                                        reinson limited
# 20      tullett prebon brasil corretora de valores e c...
# 21                                       bright think ltd
# 22                                         nkforsyning as
# 23                    holdingselskabet henrik v larsen as
# 24                                      strandtorget 1 as
# 25                                           rosshavet as
# 26                                       western edge inc
# 27                                              consto as
# 28                              sommerlade consulting aps
# 29                                nano one materials corp
# ...                                                   ...
# 450226           dci umbrella fund public limited company
# 450227                                            dci llc
# 450228                            česká exportní banka as
# 450229                                  komerční banka as
# 450230                   compagnie de financement foncier
# 450231                            amundi asset management
# 450232                                                axa
# 450233                                 amundi credit euro
# 450234                    credit industriel et commercial
# 450235                        amundi oblig haut rendement
# 450236                 banque federative du credit mutuel
# 450237                                        amundi 24 m
# 450238  cassa centrale banca  credito cooperativo del ...
# 450239  mediolanum gestione fondi  societa di gestione...
# 450240                                       nibc bank nv
# 450241                                        kas bank nv
# 450242                                      kempen  co nv
# 450243                                           aegon nv
# 450244                               aegon derivatives nv
# 450245                          abn amro clearing bank nv
# 450246           stichting pensioenfonds horeca  catering
# 450247                    stichting pensioenfonds staples
# 450248        bnp paribas asset management netherlands nv
# 450249                  stichting pensioenfonds hoogovens
# 450250                            bft investment managers
# 450251    gl europe select opportunities investments sarl
# 450252                       jacma sa  spf en liquidation
# 450253                          gl europe luxembourg sarl
# 450254                          max mara international sa
# 450255              brookfield renewable supply 2 limited
#
#                                              name_capital  \
# 0                                               PRIMCOMSA
# 1                                                    TDIF
# 2                                                     BEL
# 3                                               NAVEXIMSA
# 4                                                    MGSA
# 5                                                  MSPFSA
# 6                                       ITAPPARELSLIMITED
# 7                                               VX30141AS
# 8                                        RETFTGSP500EWETF
# 9                                                   RSFRF
# 10                                                    OHI
# 11                                                   FHAS
# 12                                                     AM
# 13                                             IHSCJVILLC
# 14                                                   HHAS
# 15                                                    PAS
# 16                                            GSATFIMFCLP
# 17                                                    LNF
# 18                                                 TFIIPL
# 19                                         REINSONLIMITED
# 20       TULLETTPREBONBRASILCORRETORADEVALORESECAMBIOLTDA
# 21                                                    BTL
# 22                                                  NKFAS
# 23                                                 HHVLAS
# 24                                                   S1AS
# 25                                                    RAS
# 26                                                    WEI
# 27                                                    CAS
# 28                                                  SCAPS
# 29                                                   NOMC
# ...                                                   ...
# 450226                                           DCIUFPLC
# 450227                                             DCILLC
# 450228                                                Čáí
# 450229                                                Kčí
# 450230                      COMPAGNIEDEFINANCEMENTFONCIER
# 450231                              AMUNDIASSETMANAGEMENT
# 450232                                                AXA
# 450233                                   AMUNDICREDITEURO
# 450234                       CREDITINDUSTRIELETCOMMERCIAL
# 450235                           AMUNDIOBLIGHAUTRENDEMENT
# 450236                     BANQUEFEDERATIVEDUCREDITMUTUEL
# 450237                                          AMUNDI24M
# 450238  CASSACENTRALEBANCACREDITOCOOPERATIVODELNORDEST...
# 450239  MEDIOLANUMGESTIONEFONDISOCIETADIGESTIONEDELRIS...
# 450240                                            NIBCBNV
# 450241                                          KASBANKNV
# 450242                                               KCNV
# 450243                                            AEGONNV
# 450244                                           AEGONDNV
# 450245                                        ABNAMROCBNV
# 450246                                               SPHC
# 450247                                                SPS
# 450248                       BNPPARIBASASSETMANAGEMENTNNV
# 450249                                                SPH
# 450250                              BFTINVESTMENTMANAGERS
# 450251                                            GLESOIS
# 450252                                        JACMASASPFL
# 450253                             GLEUROPELUXEMBOURGSARL
# 450254                             MAXMARAINTERNATIONALSA
# 450255                                              BRS2L
#
#                                     name_no_punc_no_space
# 0                                               primcomsa
# 1                                      thedavidisaacsfund
# 2                                bramorenterpriseslimited
# 3                                               naveximsa
# 4                                            magalgroupsa
# 5                                              marlyspfsa
# 6                                       itapparelslimited
# 7                                              vx30141aps
# 8              rydexetftrustguggenheimsp500equalweightetf
# 9                           rydexseriesfundsretailingfund
# 10                                        olamholdingsinc
# 11                                          fireholdingas
# 12                                        aarhusmurerlaug
# 13                             indigohallscjvinvestorsllc
# 14                                     hestbechholdingaps
# 15                                          pharmatradeas
# 16               gsatacticalfixedincomemasterfundcaymanlp
# 17                                       larsnielsensfond
# 18                       temasekfinancialiiprivatelimited
# 19                                         reinsonlimited
# 20       tullettprebonbrasilcorretoradevaloresecambioltda
# 21                                         brightthinkltd
# 22                                          nkforsyningas
# 23                        holdingselskabethenrikvlarsenas
# 24                                        strandtorget1as
# 25                                            rosshavetas
# 26                                         westernedgeinc
# 27                                               constoas
# 28                                sommerladeconsultingaps
# 29                                   nanoonematerialscorp
# ...                                                   ...
# 450226                dciumbrellafundpubliclimitedcompany
# 450227                                             dcillc
# 450228                               českáexportníbankaas
# 450229                                    komerčníbankaas
# 450230                      compagniedefinancementfoncier
# 450231                              amundiassetmanagement
# 450232                                                axa
# 450233                                   amundicrediteuro
# 450234                       creditindustrieletcommercial
# 450235                           amundioblighautrendement
# 450236                     banquefederativeducreditmutuel
# 450237                                          amundi24m
# 450238  cassacentralebancacreditocooperativodelnordest...
# 450239  mediolanumgestionefondisocietadigestionedelris...
# 450240                                         nibcbanknv
# 450241                                          kasbanknv
# 450242                                         kempenconv
# 450243                                            aegonnv
# 450244                                 aegonderivativesnv
# 450245                              abnamroclearingbanknv
# 450246               stichtingpensioenfondshorecacatering
# 450247                      stichtingpensioenfondsstaples
# 450248             bnpparibasassetmanagementnetherlandsnv
# 450249                    stichtingpensioenfondshoogovens
# 450250                              bftinvestmentmanagers
# 450251         gleuropeselectopportunitiesinvestmentssarl
# 450252                            jacmasaspfenliquidation
# 450253                             gleuropeluxembourgsarl
# 450254                             maxmarainternationalsa
# 450255                  brookfieldrenewablesupply2limited
#
# [450256 rows x 6 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity
t = time.time()
similarity_score = cosine_similarity(slice_G, tf_idf_STrain[0,v], dense_output=True)
timespent = time.time() - t
print('cosine similarity takes {} seconds'.format(timespent))
# Out:
# cosine similarity takes 0.022331953048706055 seconds

# %%
max_index= similarity_score.argmax()
max_index == 0.7
# Out:
# False

# %%
# use max_index to locate G_index
G_index = x[max_index]
print(G_index)
# Out:
# 342766

# %%
similarity_score[0]
# Out:
# array([0.26080726])

# %%
test = 'A/B/C'.split('/')[-1]
l = test.split('/')
l[-1]
# Out:
# 'C'

# %%
tf_idf_STrain_pd = pd.DataFrame(tf_idf_STrain.todense(), columns = grams, index = STrain.index)

# %%
tf_idf_G_pd = pd.DataFrame(tf_idf_G.todense(), columns = grams, index = G.index)

# %%
row = tf_idf_STrain_pd.iloc[0,:]

# %% [raw]
# row[0]

# %%
A = {'financial','service'}
B = {'service','financial'}
C = {'financial','time','series'}
D = 'financialservice'
E = 'servicefinancial'
F = 'financialtimeseries'
d = set(D)
e = set(E)
f = set(F)
y = edit_distance(D,F)/len(D)
x = jaccard_distance(d,f)
print(x)
print(y)

print(z)
# Out:
# 0.25
# 0.4375
# {'a', 'e', 's', 'i', 'c', 'r', 'f', 'n', 'v', 'l'}

# %%
# convert the results of bag of words in to dataframe

Matrix = pd.DataFrame(matrix, columns = features, index = G.index)

# %%
vectorizer.stop_words_
# Out:
# {'bv', 'fund', 'gmbh', 'inc', 'limited', 'llc', 'ltd', 'srl', 'trust'}

# %%
stop_words = list(vectorizer.stop_words_ )

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450256 entries, 0 to 450255
# Columns: 238928 entries, 00 to žūb
# dtypes: int64(238928)
# memory usage: 801.5 GB

# %%
# Break down the summation, in order to find the most frequent words
# 10000 at a time
import numpy as np
iteration = int(np.ceil(Matrix.shape[0] / 10000))

total_word_count = np.zeros(Matrix.shape[1])
for i in np.arange(0,iteration):
    lower_index = int(i*10000)
    upper_index = (i+1)*10000
    print(lower_index, upper_index)
    sub_matrix = Matrix.iloc[lower_index:upper_index]
    sub_word_count = sub_matrix.sum(axis = 0)
    total_word_count = total_word_count + sub_word_count
    
# There should be some residual
res_word_count = Matrix.iloc[iteration*10000:-1].sum(axis=0)
total_word_count = total_word_count + res_word_count
# Out:
# 0 10000
# 10000 20000
# 20000 30000
# 30000 40000
# 40000 50000
# 50000 60000
# 60000 70000
# 70000 80000
# 80000 90000
# 90000 100000

# %%
450123/10000
# Out:
# 45.0123

# %%
# Test matching_procedure

Sample = STrain.sample(n=100,random_state=10)

# %%
index= find_the_word(Sample.at[63420,'name_no_punc'], Matrix)
print(index)
print(G['name_no_punc_no_space'].loc[index])
print(G.at[216462,'name_no_punc_no_space'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4638020631a8> in <module>()
# ----> 1 index= find_the_word(Sample.at[63420,'name_no_punc'], Matrix)
#       2 print(index)
#       3 print(G['name_no_punc_no_space'].loc[index])
#       4 print(G.at[216462,'name_no_punc_no_space'])
#
# NameError: name 'find_the_word' is not defined

# %%
Sample_predict = pd.DataFrame([],index = Sample.index,columns = ['predict'])
Sample_predict['predict'] = -1

for i in Sample.index:
    company = Sample.at[i,'name_no_punc']
    compare_index = find_the_word(company, Matrix)
    print(i)
    if compare_index is not None:
        print(i)
        to_compared = G['name_no_punc_no_space'].loc[compare_index]
    
        company_train = Sample.at[i,'name_no_punc_no_space']
        predict = compare_jacaard(to_compared,company_train,0.1)
        Sample_predict.at[i,'predict'] = predict
# Out:
# 33226
# 33226
# 64804
# 64804
# 39763
# 39763
# 51270
# 51270
# 9698
# 9698
# 5948
# 5948
# 27955
# 27955
# 55001
# 55001
# 50875
# 50875
# 47755
# 47755
# 29430
# 29430
# 32953
# 32953
# 6808
# 6808
# 32927
# 32927
# 64298
# 64298
# 96492
# 96492
# 31836
# 31836
# 97276
# 97276
# 67716
# 67716
# 2144
# 2144
# 22232
# 22232
# 75323
# 75323
# 63124
# 63124
# 11476
# 11476
# 77635
# 77635
# 76295
# 76295
# 55644
# 55644
# 18506
# 18506
# 91698
# 91698
# 65435
# 90450
# 90450
# 38019
# 38019
# 63469
# 63469
# 44824
# 44824
# 87863
# 87863
# 32118
# 32118
# 66512
# 66512
# 64395
# 64395
# 63420
# 63420

# %%
Sample
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ce200716f65c> in <module>()
# ----> 1 Sample
#
# NameError: name 'Sample' is not defined

# %%
outcome, Round2 = matching_procedure(G,Sample,Matrix,0.1,4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9137d23952b0> in <module>()
#       1 # how big is round2
# ----> 2 len(Round2)
#
# NameError: name 'Round2' is not defined

# %%
merge.loc[Sample.index]
# Out:
#        train_index                                         nameSTrain  \
# 33226        33226                                  HXRUK III LIMITED
# 64804        64804                  SWARCO Traffic Funds Austria GmbH
# 39763        39763                     Ostersetzer & Co. eGse. m.b.H.
# 51270        51270                               FACADEfip ATLANTIQUE
# 9698          9698                                           Major IP
# 5948          5948                                      BMC DIFFUSION
# 27955        27955  Adept Ltd Investment Management Public Limited...
# 55001        55001                                   Silm. Oyj Global
# 50875        50875                                     Ferrari S.p.A.
# 47755        47755  Asso ciation de Commercialisation Holding de P...
# 29430        29430                    GLGfund Shishapangma Investment
# 32953        32953                                             3IF IC
# 6808          6808                        Corporation Heavy Haul NCSG
# 32927        32927             THE TRUST FAMILY PENSION Trust FIENNES
# 64298        64298                                       EARL SALGUES
# 96492        96492                                     Twin Realty AL
# 31836        31836     Starling Gold Asset Mana gement Equity Limited
# 97276        97276                            ALMANSA PHOTOSOLAR S.L.
# 67716        67716                            AMT Piirainen Global Oy
# 2144          2144                             Unitas DWC Cons. - LLC
# 22232        22232                         Niagara Group Equity, L.P.
# 75323        75323                                          GSG m.b.H
# 63124        63124                                    Jump stone B.V.
# 11476        11476                                  JG Maier & Co. KG
# 77635        77635                 Munst erhuis Vastgoed Capital B.V.
# 76295        76295                                          EBaOSA SA
# 55644        55644                                   Kappa Assoc., LP
# 18506        18506                                     Turkish Amer..
# 91698        91698                                       ArcRoyal Ltd
# 65435        65435                                AVZminerals Limited
# ...            ...                                                ...
# 21559        21559  Fund Impact Calvert, Inc. - Fund Samall Cap Ca...
# 55703        55703                                               CNcL
# 21372        21372      Consolidated Purecision Prod ucts Belgiumsprl
# 71431        71431                                         EXRC. S.L.
# 93541        93541                                    SUSANNE NIELSEN
# 65307        65307  Dôchodková sprvácovská spoločnosť Poštovej ban...
# 62022        62022                                         LLESSE SRL
# 91320        91320          Fidel. Funds - Global Metals & Miningpool
# 15550        15550                       Pensjonskasse Banks. LIMITED
# 58183        58183                                               CMCT
# 67759        67759               Prude ntial Reinsurance Term Company
# 52501        52501            OCMMUNICATIONS RESEAUXengineering Inve.
# 64599        64599                             LIMTIED SOLUTIONSaveva
# 54299        54299                       Cautioner Aktiebolag dapital
# 52441        52441                          THE HUGH 2009 FAMILY RUST
# 80002        80002                             FUNDc. GROWTH FUND AXA
# 77228        77228                      Enel Power Greenafrica S.r.l.
# 589            589                                        GBI 000, SL
# 98324        98324                                      Ali anzGI-DAV
# 38972        38972                             OV New Zealand Limited
# 9586          9586                                     Swedefuture AB
# 17976        17976                                    Serv Excel B.V.
# 51454        51454                                    HEDGERSEL Funds
# 59269        59269  Heisterner Tiefbhau Gesellschaft mit GmbH besc...
# 36071        36071                                       MEDIPART ApS
# 57802        57802            ANDREW'S COMMERCIAL ENTER PRISESlimited
# 10243        10243                                  ACTIV. qEuity, SL
# 39524        39524                                  EARL DE LA SOURCE
# 9102          9102                                                SDR
# 14475        14475                                APS EJEN. LINDH OLM
#
#        company_id                                              nameR
# 33226      539375                                  HXRUK III LIMITED
# 64804       84806                        SWARCO Traffic Austria GmbH
# 39763          -1                                                NaN
# 51270      210136                              FIP FACADE ATLANTIQUE
# 9698           -1                                                NaN
# 5948       353477                                      BMC DIFFUSION
# 27955          -1                                                NaN
# 55001       16000                                     Silmäasema Oyj
# 50875          -1                                                NaN
# 47755      454000  Association de Commercialisation de Pneus et L...
# 29430          -1                                                NaN
# 32953      559102                             3Ps Investment Fund IC
# 6808           -1                                                NaN
# 32927      143493                   THE FIENNES FAMILY PENSION TRUST
# 64298      422465                                       EARL SALGUES
# 96492      127704                        Twin Realty Associates, LLC
# 31836       26884             Starling Gold Asset Management Limited
# 97276      557550                   ALMANSA PHOTOSOLAR PEGASUS, S.L.
# 67716      216135                                   AMT Piirainen Oy
# 2144       543751                        Unitas Consulting DWC - LLC
# 22232      522134                                Niagara Group, L.P.
# 75323      310626    GSG Gesellschaft Schwäbische Gastlichkeit m.b.H
# 63124          -1                                                NaN
# 11476      532468                          Josef Maier GmbH & Co. KG
# 77635      429742                          Munsterhuis Vastgoed B.V.
# 76295      169788                                          EBROSA SA
# 55644          -1                                                NaN
# 18506      340783                     Turkish American Society, Inc.
# 91698      477679                                           ArcRoyal
# 65435          -1                                                NaN
# ...           ...                                                ...
# 21559      282166  Calvert Impact Fund, Inc. - Calvert Small Cap ...
# 55703          -1                                                NaN
# 21372      252260       Consolidated Precision Products Belgium SPRL
# 71431          -1                                                NaN
# 93541          -1                                                NaN
# 65307      595582  Dôchodková správcovská spoločnosť Poštovej ban...
# 62022          -1                                                NaN
# 91320      454438       Fidelity Funds - Global Metals & Mining Pool
# 15550      255080                         Norges Banks Pensjonskasse
# 58183          -1                                                NaN
# 67759      536418                Prudential Term Reinsurance Company
# 52501      113995                 ENGINEERING RESEAUX COMMUNICATIONS
# 64599      218918                            AVEVA SOLUTIONS LIMITED
# 54299          -1                                                NaN
# 52441      325417                 THE HUGH MULLENS 2009 FAMILY TRUST
# 80002          -1                                                NaN
# 77228      609970                     Enel Green Power Africa S.r.l.
# 589        549004                                     GBI 9000, S.L.
# 98324      443252                                AllianzGI-Fonds DAV
# 38972      590708                            OMV New Zealand Limited
# 9586         8582                                     Swedefuture AB
# 17976      634151                                     ServExcel B.V.
# 51454      383175                                          HEDGERSEL
# 59269          -1                                                NaN
# 36071          -1                                                NaN
# 57802       17967            ANDREW'S COMMERCIAL ENTERPRISES LIMITED
# 10243          -1                                                NaN
# 39524          -1                                                NaN
# 9102       622056                                 SCI DES REMIEGERES
# 14475      476372                             LINDHOLM EJENDOMME APS
#
# [100 rows x 4 columns]

# %%
Sample.head()
# Out:
#        train_index                                               name  \
# 20353        20353  BB PRINCIPI DI FEUDO SOCIETA' AGRICOLA A RESPO...
# 93040        93040                                     bMOLINOX - SRL
# 51054        51054                    GbmH Holding SCB Inte. & Co. KG
# 82879        82879                     Matias Fastighets Company 2 AB
# 82312        82312               Macro - Multi advisers Opportunities
#
#        company_id                                       name_no_punc  \
# 20353      393379  BB PRINCIPI DI FEUDO SOCIETA AGRICOLA A RESPON...
# 93040      189514                                      bMOLINOX  SRL
# 51054       85240                       GbmH Holding SCB Inte  Co KG
# 82879      445985                     Matias Fastighets Company 2 AB
# 82312       95736                Macro  Multi advisers Opportunities
#
#                                             name_capital  \
# 20353  BBPRINCIPIDIFEUDOSOCIETAAGRICOLAARESPONSABILIT...
# 93040                                         MOLINOXSRL
# 51054                                         GHHSCBICKG
# 82879                                             MFC2AB
# 82312                                                MMO
#
#                                    name_no_punc_no_space  predict  loss
# 20353  bbprincipidifeudosocietaagricolaaresponsabilit...       -1     1
# 93040                                        bmolinoxsrl       -1     1
# 51054                             gbmhholdingscbintecokg       -1     1
# 82879                         matiasfastighetscompany2ab       -1     1
# 82312                    macromultiadvisersopportunities    11191     5

# %%
 # Count of new document
new_doc = ['FIDC IIIllc'.lower()]
new_count  = vectorizer.transform(new_doc).todense()

# %%
import numpy as np
np.matmul(Matrix,np.transpose(new_count))

# %%
vectorizer.vocabulary_['financial']
# Out:
# 77950

# %%
len(vectorizer.get_feature_names())
# Out:
# 238937

# %%
find_the_word = 'financial'
vectorizer.vocabulary_ [find_the_word]

G.loc[264227]

# %%
location = vectorizer.vocabulary_ [find_the_word]
features[location]
# Out:
# 'financial'

# %%
# all the company in ground truth, and all the vocabularies
import numpy as np
np.argmax(predict)
predict[3]
# Out:
# 432988

# %%
if find_the_word in features:
    Index = Matrix[Matrix[find_the_word]>=1]
else:
    print('no such word')

# %%
import time

# %%
t = time.time()
Index = Matrix[Matrix[find_the_word]>=1].index
Financial = G.loc[Index]
elapsed = time.time() - t
print('time spent for computing this is', elapsed)
# Out:
# time spent for computing this is 2.596104860305786

# %%
G['company_id'][264277]
# Out:
# 448627

# %%
G.loc[G['company_id']==264277]
# Out:
#         company_id                      name              name_no_punc  \
# 406184      264277  Blanchard Aid Propco LLC  blanchard aid propco llc
#
#        name_capital  name_no_punc_no_space
# 406184       BAPLLC  blanchardaidpropcollc

# %%
t = time.time()
Index = Matrix[Matrix[find_the_word]>=1]
Financial = G.loc[Index.index]
elapsed = time.time() - t
print('time spent for computing this is', elapsed)
# Out:
# time spent for computing this is 1.97940993309021

# %%
Financial
# Out:
#         company_id                                               name  \
# 18          260264             Temasek Financial (II) Private Limited
# 139         135139                             Nidaros Financial S.A.
# 150         179135                              VANARES FINANCIAL LTD
# 266         469229                      Chatham Financial Europe, Ltd
# 443         529778                        Lykke Financial Capital IVS
# 2295        621087                  Resource Financial Services, Inc.
# 3945        245201                      REWARD FINANCIAL SERVICES LTD
# 4088        496479                       AXIOM FINANCIAL SERVICES LTD
# 4107        527195                 ISLAND FINANCIAL SOLUTIONS LIMITED
# 4239         75144                    FINANCIAL ADVICE CENTRE LIMITED
# 4243        442098                   BERRY FINANCIAL PLANNING LIMITED
# 4244        186796    BARBICAN INDEPENDENT FINANCIAL ADVISORS LIMITED
# 4486         72892                     TruMark Financial Credit Union
# 4841        212857                           Vectra Financial Limited
# 4953        391494                             Saraju Financial Corp.
# 5037        567074                 Yunfeng Financial Holdings Limited
# 5103        432239                             KT Financial Group LTD
# 5349         70865                          RG Financial Services LLC
# 5640        556006                                  BBC Financial Inc
# 5723        348117  Financial Structured Solutions Co. For General...
# 5778         93098          Aegean Financial Enterprises Corporatiopn
# 5942        477300                            Compeer Financial, FLCA
# 7175        376047                                Fogo Financial S.A.
# 7452        489783                              Thisbe Financial Inc.
# 7961        108778                       Power Financial Credit Union
# 8091        199265                     Financial Services Holding A/S
# 8164        563592                             Compeer Financial, PCA
# 8217        476131                    Picobe financial solutions B.V.
# 8323        179131                   Atlas Financial Investments, LLC
# 8585        337087                      Coppergate Financial Group AB
# ...            ...                                                ...
# 447680      480538                      Basswood Financial Fund, L.P.
# 447819      223146              Nomura Global Financial Products Inc.
# 447871       29852  Society for Worldwide Interbank Financial Tele...
# 448184      312681                            Ellington Financial LLC
# 448315      266528                  Citigroup Financial Products Inc.
# 448387      261999                             Magnetar Financial LLC
# 448642      392050                     FTN Financial Securities Corp.
# 448700        2376                 Principal Financial Services, Inc.
# 448876      175249            Swiss Re Financial Products Corporation
# 448881       27508     Cargill Financial Services International, Inc.
# 448943      393267                    People's United Financial, Inc.
# 448952       91478                 TOYOTA FINANCIAL SERVICES (UK) PLC
# 449100      263641       Tetragon Financial Group Master Fund Limited
# 449172      152442         T.Rowe Price Financial Services Fund, Inc.
# 449198      331574              John Hancock Financial Services, Inc.
# 449199      539825           Harley-Davidson Financial Services, Inc.
# 449210        5729                First Niagara Financial Group, Inc.
# 449297      307913        The Hartford Financial Services Group, Inc.
# 449332      504803                       AIG Financial Products Corp.
# 449370      451357                             Colony Financial, Inc.
# 449390       91260                 Fairfax Financial Holdings Limited
# 449444        1988         Caterpillar Financial Services Corporation
# 449446      640368            Boston Private Financial Holdings, Inc.
# 449510      382174                   Tiptree Financial Partners, L.P.
# 449696      512870                    Mackenzie Financial Corporation
# 449726       45713                     KKR Financial CLO 2006-1, Ltd.
# 449760      317225   First Allmerica Financial Life Insurance Company
# 449853      391363                  Capital One Financial Corporation
# 449899      345912     Genworth Financial International Holdings, LLC
# 450076      473486                          NLV Financial Corporation
#
#                                              name_no_punc
# 18                   Temasek Financial II Private Limited
# 139                                  Nidaros Financial SA
# 150                                 VANARES FINANCIAL LTD
# 266                          Chatham Financial Europe Ltd
# 443                           Lykke Financial Capital IVS
# 2295                      Resource Financial Services Inc
# 3945                        REWARD FINANCIAL SERVICES LTD
# 4088                         AXIOM FINANCIAL SERVICES LTD
# 4107                   ISLAND FINANCIAL SOLUTIONS LIMITED
# 4239                      FINANCIAL ADVICE CENTRE LIMITED
# 4243                     BERRY FINANCIAL PLANNING LIMITED
# 4244      BARBICAN INDEPENDENT FINANCIAL ADVISORS LIMITED
# 4486                       TruMark Financial Credit Union
# 4841                             Vectra Financial Limited
# 4953                                Saraju Financial Corp
# 5037                   Yunfeng Financial Holdings Limited
# 5103                               KT Financial Group LTD
# 5349                            RG Financial Services LLC
# 5640                                    BBC Financial Inc
# 5723    Financial Structured Solutions Co For General ...
# 5778            Aegean Financial Enterprises Corporatiopn
# 5942                               Compeer Financial FLCA
# 7175                                    Fogo Financial SA
# 7452                                 Thisbe Financial Inc
# 7961                         Power Financial Credit Union
# 8091                        Financial Services Holding AS
# 8164                                Compeer Financial PCA
# 8217                        Picobe financial solutions BV
# 8323                      Atlas Financial Investments LLC
# 8585                        Coppergate Financial Group AB
# ...                                                   ...
# 447680                         Basswood Financial Fund LP
# 447819               Nomura Global Financial Products Inc
# 447871  Society for Worldwide Interbank Financial Tele...
# 448184                            Ellington Financial LLC
# 448315                   Citigroup Financial Products Inc
# 448387                             Magnetar Financial LLC
# 448642                      FTN Financial Securities Corp
# 448700                   Principal Financial Services Inc
# 448876            Swiss Re Financial Products Corporation
# 448881       Cargill Financial Services International Inc
# 448943                       Peoples United Financial Inc
# 448952                   TOYOTA FINANCIAL SERVICES UK PLC
# 449100       Tetragon Financial Group Master Fund Limited
# 449172            TRowe Price Financial Services Fund Inc
# 449198                John Hancock Financial Services Inc
# 449199              HarleyDavidson Financial Services Inc
# 449210                  First Niagara Financial Group Inc
# 449297          The Hartford Financial Services Group Inc
# 449332                        AIG Financial Products Corp
# 449370                               Colony Financial Inc
# 449390                 Fairfax Financial Holdings Limited
# 449444         Caterpillar Financial Services Corporation
# 449446              Boston Private Financial Holdings Inc
# 449510                      Tiptree Financial Partners LP
# 449696                    Mackenzie Financial Corporation
# 449726                        KKR Financial CLO 20061 Ltd
# 449760   First Allmerica Financial Life Insurance Company
# 449853                  Capital One Financial Corporation
# 449899      Genworth Financial International Holdings LLC
# 450076                          NLV Financial Corporation
#
# [1650 rows x 3 columns]

# %%
# How long does it take to apply bag of words to the whole G
import timeit
matrix_G = vectorizer.fit_transform(G['name']).todense()

# %%
G.shape
# Out:
# (450256, 2)

# %%
# join and remove lowercase
import string
def join_and_remove_low(X):
    y = ''.join(X)
    
    z = y.translate(None,string.ascii_lowercase)
    zz = z.translate(None,',.-()"')

result = Sample_G['name'].apply(join_and_remove_low)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-d40e43c714fb> in <module>()
#       6     zz = z.translate(None,',.-()"')
#       7
# ----> 8 result = Sample_G['name'].apply(join_and_remove_low)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-44-d40e43c714fb> in join_and_remove_low(X)
#       3 def join_and_remove_low(X):
#       4     y = ''.join(X)
# ----> 5     z = y.translate(None,string.ascii_lowercase)
#       6     zz = z.translate(None,',.-()"')
#       7
#
# TypeError: translate() takes exactly one argument (2 given)

# %%
print(string.ascii_lowercase)
# Out:
# abcdefghijklmnopqrstuvwxyz

# %%
import string
ss = 'AbCdEfG'
t = ss.maketrans(string.ascii_lowercase, None )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-c859992ce73e> in <module>()
#       1 import string
#       2 ss = 'AbCdEfG'
# ----> 3 t = ss.maketrans(string.ascii_lowercase, None )
#
# TypeError: maketrans() argument 2 must be str, not None

# %%
#### Ideas
# remove sapce and punctuations
# remove lower cases
# compare with levenshein distance
